# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
# 1. 數據加載與處理
def load_and_preprocess_data(file_path):
    # 讀取資料
    df = pd.read_csv(file_path)

    # 民國年轉西元年
    def convert_date(x):
        parts = x.split('/')
        year = int(parts[0]) + 1911  # 民國年轉換
        return f"{year}-{parts[1]}-{parts[2]}"

    df['日期'] = df['日期'].apply(convert_date)
    df['日期'] = pd.to_datetime(df['日期'], format='%Y-%m-%d')

    # 添加時間特徵
    df['天數'] = (df['日期'] - df['日期'].min()).dt.days
    df['月'] = df['日期'].dt.month
    df['日'] = df['日期'].dt.day
    df['星期'] = df['日期'].dt.weekday

    # 添加滯後特徵
    for i in range(1, 8):
        df[f'滯後{i}日平均價'] = df['平均價'].shift(i)

    # 創建目標變量: 7天後的平均價
    df['7日後平均價'] = df['平均價'].shift(-7)

    # 去除無效數據
    df = df.dropna()

    return df

# 創建序列數據
def create_sequences(data, target, time_steps=7):
    sequences = []
    labels = []
    for i in range(len(data) - time_steps):
        seq = data[i:i + time_steps]
        label = target[i + time_steps]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

# %%
# 2. 訓練與驗證
def train_and_evaluate_model(df):
    # 分割數據集
    train_data = df[df['日期'] < datetime(2022, 1, 1)]
    val_data = df[(df['日期'] >= datetime(2022, 1, 1)) & (df['日期'] < datetime(2024, 1, 1))]
    test_data = df[df['日期'] >= datetime(2024, 1, 1)]

    # 特徵與目標
    features = ['天數', '月', '日', '星期'] + [f'滯後{i}日平均價' for i in range(1, 8)]
    X_train_raw, y_train_raw = train_data[features].values, train_data['7日後平均價'].values
    X_val_raw, y_val_raw = val_data[features].values, val_data['7日後平均價'].values
    X_test_raw = test_data[features].values

    # 創建序列數據
    time_steps = 7
    X_train, y_train = create_sequences(X_train_raw, y_train_raw, time_steps)
    X_val, y_val = create_sequences(X_val_raw, y_val_raw, time_steps)

    # 構建 LSTM 模型
    model = Sequential([
        LSTM(50, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
        LSTM(50, activation='relu'),
        Dense(1)  # 單輸出回歸
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mse'])

    # 訓練模型
    model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val), verbose=1)

    return model, X_test_raw, test_data, time_steps

# %%
# 3. 預測與輸出
def predict_and_save_results(model, X_test_raw, test_data, output_path, time_steps):
    # 創建測試集序列
    X_test, _ = create_sequences(X_test_raw, np.zeros(len(X_test_raw)), time_steps)

    # 預測測試集
    test_data = test_data.iloc[time_steps:]  # 因序列有偏移
    test_data['預測價'] = model.predict(X_test).flatten()

    # 檢查是否有真實值可用於計算 RMSE
    if '7日後平均價' in test_data.columns:
        rmse = mean_squared_error(test_data['7日後平均價'], test_data['預測價'], squared=False)
        print(f"Test RMSE: {rmse}")
    else:
        print("Test dataset does not contain true values for RMSE calculation.")

    # 保存結果
    test_data[['日期', '預測價']].to_csv(output_path, index=False)
    print(f"Predictions saved to {output_path}")

# %%
# 主程式
file_path = "data/甘藍初秋_台北一日交易行情.csv"
output_path = "output_LSTM.csv"

# 數據加載與處理
df = load_and_preprocess_data(file_path)

# 訓練與驗證
model, X_test_raw, test_data, time_steps = train_and_evaluate_model(df)

# 預測與保存結果
predict_and_save_results(model, X_test_raw, test_data, output_path, time_steps)
# Out:
# Epoch 1/50
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 5656.8955 - mse: 5656.8955 - val_loss: 436.1919 - val_mse: 436.1919
# Epoch 2/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 141.3223 - mse: 141.3223 - val_loss: 170.3281 - val_mse: 170.3281
# Epoch 3/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 117.7543 - mse: 117.7543 - val_loss: 162.2444 - val_mse: 162.2444
# Epoch 4/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 84.8074 - mse: 84.8074 - val_loss: 114.1284 - val_mse: 114.1284
# Epoch 5/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 93.5606 - mse: 93.5606 - val_loss: 94.2019 - val_mse: 94.2019
# Epoch 6/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 82.3968 - mse: 82.3968 - val_loss: 105.2047 - val_mse: 105.2047
# Epoch 7/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 69.0499 - mse: 69.0499 - val_loss: 92.8175 - val_mse: 92.8175
# Epoch 8/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 75.3204 - mse: 75.3204 - val_loss: 127.9136 - val_mse: 127.9136
# Epoch 9/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 73.5043 - mse: 73.5043 - val_loss: 80.0524 - val_mse: 80.0524
# Epoch 10/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.6592 - mse: 62.6592 - val_loss: 99.3634 - val_mse: 99.3634
# Epoch 11/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 71.9955 - mse: 71.9955 - val_loss: 89.0652 - val_mse: 89.0652
# Epoch 12/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.1853 - mse: 60.1853 - val_loss: 204.0095 - val_mse: 204.0095
# Epoch 13/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 83.2680 - mse: 83.2680 - val_loss: 82.5660 - val_mse: 82.5660
# Epoch 14/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.7762 - mse: 58.7762 - val_loss: 132.5216 - val_mse: 132.5216
# Epoch 15/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.1910 - mse: 60.1910 - val_loss: 89.6047 - val_mse: 89.6047
# Epoch 16/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 55.6166 - mse: 55.6166 - val_loss: 82.2572 - val_mse: 82.2572
# Epoch 17/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.4983 - mse: 51.4983 - val_loss: 424.3130 - val_mse: 424.3130
# Epoch 18/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 163.0115 - mse: 163.0115 - val_loss: 82.8859 - val_mse: 82.8859
# Epoch 19/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 69.3265 - mse: 69.3265 - val_loss: 78.2809 - val_mse: 78.2809
# Epoch 20/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.5906 - mse: 56.5906 - val_loss: 171.6308 - val_mse: 171.6308
# Epoch 21/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 63.4997 - mse: 63.4997 - val_loss: 184.7170 - val_mse: 184.7170
# Epoch 22/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 74.4012 - mse: 74.4012 - val_loss: 77.2507 - val_mse: 77.2507
# Epoch 23/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.9068 - mse: 50.9068 - val_loss: 101.4940 - val_mse: 101.4940
# Epoch 24/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 66.6118 - mse: 66.6118 - val_loss: 488.4127 - val_mse: 488.4127
# Epoch 25/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 114.7084 - mse: 114.7084 - val_loss: 73.0344 - val_mse: 73.0344
# Epoch 26/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.8681 - mse: 54.8681 - val_loss: 72.4855 - val_mse: 72.4855
# Epoch 27/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.1013 - mse: 49.1013 - val_loss: 710.6149 - val_mse: 710.6149
# Epoch 28/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 282.9299 - mse: 282.9299 - val_loss: 130.3607 - val_mse: 130.3607
# Epoch 29/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 71.5818 - mse: 71.5818 - val_loss: 89.6602 - val_mse: 89.6602
# Epoch 30/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.4059 - mse: 60.4059 - val_loss: 97.3843 - val_mse: 97.3843
# Epoch 31/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.6496 - mse: 59.6496 - val_loss: 84.8130 - val_mse: 84.8130
# Epoch 32/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.5197 - mse: 57.5197 - val_loss: 89.5857 - val_mse: 89.5857
# Epoch 33/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 66.4261 - mse: 66.4261 - val_loss: 90.5548 - val_mse: 90.5548
# Epoch 34/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.0303 - mse: 57.0303 - val_loss: 80.4047 - val_mse: 80.4047
# Epoch 35/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.0039 - mse: 58.0039 - val_loss: 124.9755 - val_mse: 124.9755
# Epoch 36/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 62.7883 - mse: 62.7883 - val_loss: 83.7866 - val_mse: 83.7866
# Epoch 37/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.0485 - mse: 61.0485 - val_loss: 75.8911 - val_mse: 75.8911
# Epoch 38/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 52.8724 - mse: 52.8724 - val_loss: 97.0625 - val_mse: 97.0625
# Epoch 39/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.4277 - mse: 57.4277 - val_loss: 92.7546 - val_mse: 92.7546
# Epoch 40/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.1978 - mse: 56.1978 - val_loss: 81.2880 - val_mse: 81.2880
# Epoch 41/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.8533 - mse: 49.8533 - val_loss: 85.7747 - val_mse: 85.7747
# Epoch 42/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.9552 - mse: 58.9552 - val_loss: 97.6013 - val_mse: 97.6013
# Epoch 43/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.1479 - mse: 60.1479 - val_loss: 75.8283 - val_mse: 75.8283
# Epoch 44/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 57.4246 - mse: 57.4246 - val_loss: 81.4684 - val_mse: 81.4684
# Epoch 45/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.6012 - mse: 53.6012 - val_loss: 122.1439 - val_mse: 122.1439
# Epoch 46/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.3332 - mse: 59.3332 - val_loss: 107.5316 - val_mse: 107.5316
# Epoch 47/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.4653 - mse: 54.4653 - val_loss: 113.2581 - val_mse: 113.2581
# Epoch 48/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.3398 - mse: 54.3398 - val_loss: 184.2668 - val_mse: 184.2668
# Epoch 49/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 76.7316 - mse: 76.7316 - val_loss: 99.7958 - val_mse: 99.7958
# Epoch 50/50
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 53.8995 - mse: 53.8995 - val_loss: 191.5066 - val_mse: 191.5066
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Test RMSE: 15.258719513079589
# Predictions saved to output_LSTM.csv
# C:\Users\User\AppData\Local\Temp\ipykernel_6432\104465750.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['預測價'] = model.predict(X_test).flatten()
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
